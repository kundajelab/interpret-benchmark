# %%
#!/usr/bin/env python
from __future__ import division, print_function, absolute_import
import numpy as np
import h5py
import simdna.synthetic as synthetic
from sklearn.metrics import (
    roc_auc_score, average_precision_score,
    roc_curve, precision_recall_curve)
import re
from collections import OrderedDict, defaultdict

def load_motif_matches(motif_match_file, doprint=False):
        """
        Loads a homer motif match file into an ordered dictionary with key as se
quence name
        and value as list of dictionaries each containing the keys - motif, sequ
ence,
        begin (0-indexed inclusive begin index of motif), end (0-indexed exclusi
ve end index),
        strand (+ or -), seqval. Each dictionary
        represents one motif match on that sequence
        """
        motif_matches = OrderedDict()
        fp = open(motif_match_file, "r")
        if doprint:
                print("#Loading " + motif_match_file + " ...")
        numlines = 0
        for line in fp:
                match = re.match("((\w|\-)+)\s+((\w|\:|\-)+)\s+(\d+)\s+(\d+)\s+(\+|\-)\s+.+\s+(\w+)$", line)
                if match:
                        numlines = numlines + 1
                        motif = match.group(1)
                        sequence = match.group(3)
                        begin = int(match.group(5))
                        end = int(match.group(6))
                        strand = match.group(7)
                        seqval = match.group(8)
                        entry = dict()
                        entry['motif'] = motif
                        entry['sequence'] = sequence
                        entry['begin'] = begin-1 # Homer motif match file is 1 indexed, convert to 0
                        entry['end'] = end # Homer motif match file is 1 indexed AND inclusive, convert to 0 and exclusive
                        entry['strand'] = strand
                        entry['seqval'] = seqval
                        if sequence not in motif_matches:
                                motif_matches[sequence] = list()
                        motif_matches[sequence].append(entry)
        fp.close()
        if doprint:
                print("#Loaded " + str(numlines) + " motif matches in " + str(len(motif_matches.keys())) + " sequences")
        return motif_matches

# %%
def rename(label):
    match=re.match('.*_(chr.*)$',label)
    if match:
        return match.group(1)
    else:
        return ""

# %%
def get_relevant_labels_in_order_of_scores(labels, motif_matches):
    relevant_labels_list=[]
    relevant_indices_list=[]
    sequence_index=0
    positive_labels=[]
    for label in motif_matches.keys():
        positive_labels.append(label)
    positive_labels_set = set(positive_labels)
    print("Motif matches sequences are " + str(len(positive_labels_set)))
    print("Supplied labels are " + str(len(labels)))
    for sequence_label in labels:
        if sequence_label in positive_labels_set:
            if sequence_index==731:
                print(sequence_index)
            relevant_indices_list.append(sequence_index)
            relevant_labels_list.append(sequence_label)
        else:
            print("Did not find this label in motif matches: " + sequence_label)
        sequence_index=sequence_index+1
    print (len(relevant_indices_list))
    print (len(relevant_labels_list))
    return relevant_indices_list, relevant_labels_list

# %%
def get_relevant_scores(relevant_indices_list, scores, seq_len=400):
    relevant_scores=np.zeros((len(relevant_indices_list),seq_len))
    index=0
    for scores_index in relevant_indices_list:
        relevant_scores[index]=scores[scores_index]
        index=index+1
    return relevant_scores

# %%
scores_file='/users/eprakash/projects/benchmarking/notebooks/momma_dragonn/GM12878.adaptDeepSea.posIG.h5'
h5f = h5py.File(scores_file,'r')
initial_labels=np.array(h5f.get("labels"))
size=len(initial_labels)
labels=np.empty(size,dtype=object)
#fpointer = open("/users/eprakash/projects/benchmarking/newdata/K562/K562_pos_labels_truncated.txt", "w")
for index in range(0, size):
    labels[index]=rename(initial_labels[index])
    #fpointer.write(str(labels[index]) + "\n")
#Sanity check
#fpointer.close()
print (labels.shape)

original_grad_times_input_scores=np.array(h5f.get("grad_times_inp"))
original_rescale_all_scores=np.array(h5f.get("rescale_all_layers_multiref_10"))
original_rescale_conv_scores=np.array(h5f.get("rescale_conv_revealcancel_fc_multiref_10"))

ig_scores=np.array(h5f.get("integrated_gradients10_multiref_10"))
h5f.close()

seq_len=original_grad_times_input_scores.shape[1]
motif_matches=load_motif_matches('/users/eprakash/projects/benchmarking/newdata/GM12878/400bp/GM12878.motif.matches.txt', True)
initial_seq_ids_of_interest = motif_matches.keys()
seq_ids_of_interest=[]
for id in initial_seq_ids_of_interest:
    seq_ids_of_interest.append(rename(id))
print(len(seq_ids_of_interest))
# Out:
# (74493,)
# #Loading /users/eprakash/projects/benchmarking/newdata/GM12878/400bp/GM12878.motif.matches.txt ...
# #Loaded 1843233 motif matches in 68407 sequences
# 68407

# %%
seq_ids_of_interest_set = set(seq_ids_of_interest)
relevant_indices_list, relevant_labels_list=get_relevant_labels_in_order_of_scores(labels, motif_matches)
#Changed later: reducing seq_ids_of_interest to those which are common to motif matches and labels
seq_ids_of_interest = relevant_labels_list
seq_ids_of_interest_set = set(relevant_labels_list)
ig_h5f=h5py.File('/users/eprakash/projects/benchmarking/notebooks/momma_dragonn/top1kposlabels_GM12878_1kb','r')
ig_seq_ids_of_interest=list(ig_h5f.get("labels"))
grad_times_input_scores=get_relevant_scores(relevant_indices_list, original_grad_times_input_scores, seq_len)
rescale_all_scores=get_relevant_scores(relevant_indices_list, original_rescale_all_scores, seq_len)
rescale_conv_scores=get_relevant_scores(relevant_indices_list, original_rescale_conv_scores, seq_len)
#reveal_cancel_scores=get_relevant_scores(relevant_indices_list, original_reveal_cancel_scores, seq_len)
#guided_backprop_scores=get_relevant_scores(relevant_indices_list, original_guided_backprop_scores, seq_len)

print (rescale_conv_scores.shape)
# Out:
# Motif matches sequences are 68407
# Supplied labels are 74493
# Did not find this label in motif matches: chr1:163674123-163674523
# Did not find this label in motif matches: chr1:30984308-30984708
# Did not find this label in motif matches: chr1:11712761-11713161
# Did not find this label in motif matches: chr1:93232637-93233037
# Did not find this label in motif matches: chr1:29475130-29475530
# Did not find this label in motif matches: chr1:207068767-207069167
# Did not find this label in motif matches: chr10:80534640-80535040
# Did not find this label in motif matches: chr1:3208265-3208665
# Did not find this label in motif matches: chr22:50506364-50506764
# Did not find this label in motif matches: chr1:2306579-2306979
# Did not find this label in motif matches: chr1:151876973-151877373
# Did not find this label in motif matches: chr1:167694766-167695166
# Did not find this label in motif matches: chr1:167976850-167977250
# Did not find this label in motif matches: chr1:88370728-88371128
# Did not find this label in motif matches: chr1:150620928-150621328
# Did not find this label in motif matches: chr1:38760630-38761030
# Did not find this label in motif matches: chr8:142623219-142623619
# Did not find this label in motif matches: chr10:133741682-133742082
# Did not find this label in motif matches: chr1:68518966-68519366
# Did not find this label in motif matches: chr14:104106973-104107373
# Did not find this label in motif matches: chr1:152942559-152942959
# Did not find this label in motif matches: chr1:64757607-64758007
# Did not find this label in motif matches: chr11:119728470-119728870
# Did not find this label in motif matches: chr1:98220438-98220838
# Did not find this label in motif matches: chr15:31325823-31326223
# Did not find this label in motif matches: chr1:211739243-211739643
# Did not find this label in motif matches: chr1:11033108-11033508
# Did not find this label in motif matches: chr12:6865922-6866322
# Did not find this label in motif matches: chr10:78977264-78977664
# Did not find this label in motif matches: chr1:219711784-219712184
# Did not find this label in motif matches: chr1:46985669-46986069
# Did not find this label in motif matches: chr15:45574204-45574604
# Did not find this label in motif matches: chr1:35528709-35529109
# Did not find this label in motif matches: chr1:41895549-41895949
# Did not find this label in motif matches: chr1:9500887-9501287
# Did not find this label in motif matches: chr1:119731056-119731456
# Did not find this label in motif matches: chr1:78454975-78455375
# Did not find this label in motif matches: chr1:81045795-81046195
# Did not find this label in motif matches: chr1:87115249-87115649
# Did not find this label in motif matches: chr1:7270020-7270420
# Did not find this label in motif matches: chr1:46101572-46101972
# Did not find this label in motif matches: chr1:159928742-159929142
# Did not find this label in motif matches: chr1:16129358-16129758
# Did not find this label in motif matches: chr10:79420941-79421341
# Did not find this label in motif matches: chr10:127420402-127420802
# Did not find this label in motif matches: chr1:219907639-219908039
# Did not find this label in motif matches: chr1:59399905-59400305
# Did not find this label in motif matches: chr1:36908887-36909287
# Did not find this label in motif matches: chr7:150033762-150034162
# Did not find this label in motif matches: chr1:64525730-64526130
# Did not find this label in motif matches: chr20:62351538-62351938
# Did not find this label in motif matches: chr1:15649508-15649908
# Did not find this label in motif matches: chr1:50901610-50902010
# Did not find this label in motif matches: chr1:59920298-59920698
# Did not find this label in motif matches: chr1:167927948-167928348
# Did not find this label in motif matches: chr1:149787776-149788176
# Did not find this label in motif matches: chr1:4552428-4552828
# Did not find this label in motif matches: chr1:62214581-62214981
# Did not find this label in motif matches: chr1:16409448-16409848
# Did not find this label in motif matches: chr10:128464206-128464606
# Did not find this label in motif matches: chr1:86574064-86574464
# Did not find this label in motif matches: chr11:3215936-3216336
# Did not find this label in motif matches: chr1:175487977-175488377
# Did not find this label in motif matches: chr1:26336826-26337226
# Did not find this label in motif matches: chr11:18727303-18727703
# Did not find this label in motif matches: chr1:160144887-160145287
# Did not find this label in motif matches: chr1:112320706-112321106
# Did not find this label in motif matches: chr1:40340159-40340559
# Did not find this label in motif matches: chr1:12360282-12360682
# Did not find this label in motif matches: chr1:12401237-12401637
# Did not find this label in motif matches: chr7:63764444-63764844
# Did not find this label in motif matches: chr1:45125339-45125739
# Did not find this label in motif matches: chr1:71156828-71157228
# Did not find this label in motif matches: chr1:65672465-65672865
# Did not find this label in motif matches: chr14:105090886-105091286
# Did not find this label in motif matches: chr9:137369492-137369892
# Did not find this label in motif matches: chr11:57179926-57180326
# Did not find this label in motif matches: chr10:97013858-97014258
# Did not find this label in motif matches: chr1:2812438-2812838
# Did not find this label in motif matches: chr1:52562762-52563162
# Did not find this label in motif matches: chr21:44932836-44933236
# Did not find this label in motif matches: chr1:53925390-53925790
# Did not find this label in motif matches: chr1:193356026-193356426
# Did not find this label in motif matches: chr1:52831333-52831733
# Did not find this label in motif matches: chr12:57620979-57621379
# Did not find this label in motif matches: chr1:55999726-56000126
# Did not find this label in motif matches: chr1:109420842-109421242
# Did not find this label in motif matches: chr1:109786710-109787110
# Did not find this label in motif matches: chr1:63473966-63474366
# Did not find this label in motif matches: chr1:4118301-4118701
# Did not find this label in motif matches: chr1:107113181-107113581
# Did not find this label in motif matches: chr1:11630530-11630930
# Did not find this label in motif matches: chr1:10587905-10588305
# Did not find this label in motif matches: chr1:169553422-169553822
# Did not find this label in motif matches: chr7:5423266-5423666
# Did not find this label in motif matches: chr1:51003651-51004051
# Did not find this label in motif matches: chr9:129697362-129697762
# Did not find this label in motif matches: chr1:74989108-74989508
# Did not find this label in motif matches: chr1:74364510-74364910
# Did not find this label in motif matches: chr1:38748208-38748608
# Did not find this label in motif matches: chr1:20752894-20753294
# Did not find this label in motif matches: chr11:2168932-2169332
# Did not find this label in motif matches: chr1:52023765-52024165
# Did not find this label in motif matches: chr1:120819508-120819908
# Did not find this label in motif matches: chr2:206443612-206444012
# Did not find this label in motif matches: chr1:56177290-56177690
# Did not find this label in motif matches: chr1:11071731-11072131
# Did not find this label in motif matches: chr1:65702712-65703112
# Did not find this label in motif matches: chr17:13601694-13602094
# Did not find this label in motif matches: chr8:143423958-143424358
# Did not find this label in motif matches: chr21:37367309-37367709
# Did not find this label in motif matches: chr1:3246823-3247223
# Did not find this label in motif matches: chr17:42163747-42164147
# Did not find this label in motif matches: chr1:34203431-34203831
# Did not find this label in motif matches: chr1:10609813-10610213
# Did not find this label in motif matches: chr10:43233643-43234043
# Did not find this label in motif matches: chr1:14124798-14125198
# Did not find this label in motif matches: chr1:106992665-106993065
# Did not find this label in motif matches: chr10:13733903-13734303
# Did not find this label in motif matches: chr1:111494170-111494570
# Did not find this label in motif matches: chr1:183388137-183388537
# Did not find this label in motif matches: chr15:77866650-77867050
# Did not find this label in motif matches: chr1:53710275-53710675
# Did not find this label in motif matches: chr1:66511576-66511976
# Did not find this label in motif matches: chr1:227510830-227511230
# Did not find this label in motif matches: chr1:40390871-40391271
# Did not find this label in motif matches: chr1:111256836-111257236
# Did not find this label in motif matches: chr1:64596330-64596730
# Did not find this label in motif matches: chr1:70897130-70897530
# Did not find this label in motif matches: chr1:95743253-95743653
# Did not find this label in motif matches: chr1:45352169-45352569
# Did not find this label in motif matches: chr2:240783099-240783499
# Did not find this label in motif matches: chr16:4696814-4697214
# Did not find this label in motif matches: chr1:49343622-49344022
# Did not find this label in motif matches: chr1:149987101-149987501
# Did not find this label in motif matches: chr1:160602778-160603178
# Did not find this label in motif matches: chr1:3109887-3110287
# Did not find this label in motif matches: chr1:153662356-153662756
# Did not find this label in motif matches: chr10:68278891-68279291
# Did not find this label in motif matches: chr10:123948207-123948607
# Did not find this label in motif matches: chr1:95319450-95319850
# Did not find this label in motif matches: chr1:80280333-80280733
# Did not find this label in motif matches: chr20:38835838-38836238
# Did not find this label in motif matches: chr1:7200978-7201378
# Did not find this label in motif matches: chr1:242169773-242170173
# Did not find this label in motif matches: chr1:154634385-154634785
# Did not find this label in motif matches: chr17:40363562-40363962
# Did not find this label in motif matches: chr1:1255720-1256120
# Did not find this label in motif matches: chr17:79125712-79126112
# Did not find this label in motif matches: chr1:49020434-49020834
# Did not find this label in motif matches: chr1:164616133-164616533
# Did not find this label in motif matches: chr1:31849111-31849511
# Did not find this label in motif matches: chr1:85688526-85688926
# Did not find this label in motif matches: chr1:5517597-5517997
# Did not find this label in motif matches: chr1:184797805-184798205
# Did not find this label in motif matches: chr1:201597079-201597479
# Did not find this label in motif matches: chr1:34037850-34038250
# Did not find this label in motif matches: chr1:46494094-46494494
# Did not find this label in motif matches: chr7:117550-117950
# Did not find this label in motif matches: chr10:102634958-102635358
# Did not find this label in motif matches: chr1:30512185-30512585
# Did not find this label in motif matches: chr1:64196694-64197094
# Did not find this label in motif matches: chr1:1365305-1365705
# Did not find this label in motif matches: chr1:87732338-87732738
# Did not find this label in motif matches: chr1:200478744-200479144
# Did not find this label in motif matches: chr1:7617463-7617863
# Did not find this label in motif matches: chr12:124993695-124994095
# Did not find this label in motif matches: chr1:30471084-30471484
# Did not find this label in motif matches: chr1:12106888-12107288
# Did not find this label in motif matches: chr10:132416404-132416804
# Did not find this label in motif matches: chr1:44514994-44515394
# Did not find this label in motif matches: chr11:2857751-2858151
# Did not find this label in motif matches: chrX:153921161-153921561
# Did not find this label in motif matches: chr1:16505120-16505520
# Did not find this label in motif matches: chr11:69060124-69060524
# Did not find this label in motif matches: chr1:67800653-67801053
# Did not find this label in motif matches: chr1:16600104-16600504
# Did not find this label in motif matches: chr9:87659611-87660011
# Did not find this label in motif matches: chr1:54848505-54848905
# Did not find this label in motif matches: chr1:42980124-42980524
# Did not find this label in motif matches: chr1:20545992-20546392
# Did not find this label in motif matches: chr1:173247879-173248279
# Did not find this label in motif matches: chr1:111756701-111757101
# Did not find this label in motif matches: chr1:205800918-205801318
# Did not find this label in motif matches: chr9:132161101-132161501
# Did not find this label in motif matches: chr10:131683315-131683715
# Did not find this label in motif matches: chr1:9029015-9029415
# Did not find this label in motif matches: chr2:241810622-241811022
# Did not find this label in motif matches: chr1:31154099-31154499
# Did not find this label in motif matches: chr14:104424213-104424613
# Did not find this label in motif matches: chr1:189968983-189969383
# Did not find this label in motif matches: chr17:75615426-75615826
# Did not find this label in motif matches: chr1:56285672-56286072
# Did not find this label in motif matches: chr16:49856398-49856798
# Did not find this label in motif matches: chr1:109472055-109472455
# Did not find this label in motif matches: chr1:155096605-155097005
# Did not find this label in motif matches: chr1:179005770-179006170
# Did not find this label in motif matches: chr22:42128933-42129333
# Did not find this label in motif matches: chr1:21350995-21351395
# Did not find this label in motif matches: chr1:9324035-9324435
# Did not find this label in motif matches: chr1:103189793-103190193
# Did not find this label in motif matches: chr1:14437429-14437829
# Did not find this label in motif matches: chr3:127284128-127284528
# Did not find this label in motif matches: chr1:78905420-78905820
# Did not find this label in motif matches: chr10:31978926-31979326
# Did not find this label in motif matches: chr2:239175992-239176392
# Did not find this label in motif matches: chr22:29722119-29722519
# Did not find this label in motif matches: chr13:114120291-114120691
# Did not find this label in motif matches: chr1:11039647-11040047
# Did not find this label in motif matches: chr13:26895571-26895971
# Did not find this label in motif matches: chr5:1212910-1213310
# Did not find this label in motif matches: chr1:181493751-181494151
# Did not find this label in motif matches: chr11:45094648-45095048
# Did not find this label in motif matches: chr1:46939146-46939546
# Did not find this label in motif matches: chr1:23679275-23679675
# Did not find this label in motif matches: chr1:179959421-179959821
# Did not find this label in motif matches: chr19:4505927-4506327
# Did not find this label in motif matches: chr5:178576861-178577261
# Did not find this label in motif matches: chr11:70711016-70711416
# Did not find this label in motif matches: chr19:620032-620432
# Did not find this label in motif matches: chr1:29286141-29286541
# Did not find this label in motif matches: chr1:165348348-165348748
# Did not find this label in motif matches: chr1:94611308-94611708
# Did not find this label in motif matches: chr9:135551456-135551856
# Did not find this label in motif matches: chr1:19318536-19318936
# Did not find this label in motif matches: chr1:180223503-180223903
# Did not find this label in motif matches: chr10:1166173-1166573
# Did not find this label in motif matches: chr10:29409600-29410000
# Did not find this label in motif matches: chr11:64109417-64109817
# Did not find this label in motif matches: chr12:131041421-131041821
# Did not find this label in motif matches: chr1:59991427-59991827
# Did not find this label in motif matches: chr4:17781626-17782026
# Did not find this label in motif matches: chr1:20715651-20716051
# Did not find this label in motif matches: chr1:49630006-49630406
# Did not find this label in motif matches: chr1:101388186-101388586
# Did not find this label in motif matches: chr1:185131107-185131507
# Did not find this label in motif matches: chr1:170456151-170456551
# Did not find this label in motif matches: chr1:230308401-230308801
# Did not find this label in motif matches: chr1:54981398-54981798
# Did not find this label in motif matches: chr1:15146221-15146621
# Did not find this label in motif matches: chr1:45911704-45912104
# Did not find this label in motif matches: chr1:55339506-55339906
# Did not find this label in motif matches: chr1:26445898-26446298
# Did not find this label in motif matches: chr1:116835043-116835443
# Did not find this label in motif matches: chr19:16889102-16889502
# Did not find this label in motif matches: chr1:207909635-207910035
# Did not find this label in motif matches: chr1:9284951-9285351
# Did not find this label in motif matches: chr1:24785542-24785942
# Did not find this label in motif matches: chr1:31839147-31839547
# Did not find this label in motif matches: chr1:95036019-95036419
# Did not find this label in motif matches: chr1:68782794-68783194
# Did not find this label in motif matches: chr10:101071767-101072167
# Did not find this label in motif matches: chr1:204323226-204323626
# Did not find this label in motif matches: chr1:40484240-40484640
# Did not find this label in motif matches: chr1:151949590-151949990
# Did not find this label in motif matches: chrX:9895650-9896050
# Did not find this label in motif matches: chr1:117914985-117915385
# Did not find this label in motif matches: chr10:102121749-102122149
# Did not find this label in motif matches: chr20:62157767-62158167
# Did not find this label in motif matches: chr1:156036521-156036921
# Did not find this label in motif matches: chr1:6072559-6072959
# Did not find this label in motif matches: chr8:144530630-144531030
# Did not find this label in motif matches: chr17:58308583-58308983
# Did not find this label in motif matches: chr16:86515603-86516003
# Did not find this label in motif matches: chr1:181972852-181973252
# Did not find this label in motif matches: chr1:159178357-159178757
# Did not find this label in motif matches: chr10:955253-955653
# Did not find this label in motif matches: chr1:60540698-60541098
# Did not find this label in motif matches: chr1:195707591-195707991
# Did not find this label in motif matches: chr1:28822917-28823317
# Did not find this label in motif matches: chr1:17636216-17636616
# Did not find this label in motif matches: chr10:85681521-85681921
# Did not find this label in motif matches: chr3:179120472-179120872
# Did not find this label in motif matches: chr1:153113300-153113700
# Did not find this label in motif matches: chr1:168575961-168576361
# Did not find this label in motif matches: chr1:32649792-32650192
# Did not find this label in motif matches: chr8:141429225-141429625
# Did not find this label in motif matches: chr1:18673560-18673960
# Did not find this label in motif matches: chr1:47271822-47272222
# Did not find this label in motif matches: chr1:154675170-154675570
# Did not find this label in motif matches: chr3:50296903-50297303
# Did not find this label in motif matches: chr1:159677148-159677548
# Did not find this label in motif matches: chr1:95554690-95555090
# Did not find this label in motif matches: chr1:100092657-100093057
# Did not find this label in motif matches: chr1:113462086-113462486
# Did not find this label in motif matches: chr4:128047380-128047780
# Did not find this label in motif matches: chr17:4004003-4004403
# Did not find this label in motif matches: chr1:17813792-17814192
# Did not find this label in motif matches: chr1:159146567-159146967
# Did not find this label in motif matches: chr17:9239670-9240070
# Did not find this label in motif matches: chr1:20655791-20656191
# Did not find this label in motif matches: chr1:38884851-38885251
# Did not find this label in motif matches: chr1:61377084-61377484
# Did not find this label in motif matches: chr1:153886254-153886654
# Did not find this label in motif matches: chr1:27117537-27117937
# Did not find this label in motif matches: chr1:80078243-80078643
# Did not find this label in motif matches: chr1:120397824-120398224
# Did not find this label in motif matches: chr1:29628284-29628684
# Did not find this label in motif matches: chr9:123999698-124000098
# Did not find this label in motif matches: chr1:9547884-9548284
# Did not find this label in motif matches: chr1:27180895-27181295
# Did not find this label in motif matches: chr10:86936662-86937062
# Did not find this label in motif matches: chr1:97316727-97317127
# Did not find this label in motif matches: chr11:1258537-1258937
# Did not find this label in motif matches: chr1:64169598-64169998
# Did not find this label in motif matches: chr1:144985580-144985980
# Did not find this label in motif matches: chr1:44610577-44610977
# Did not find this label in motif matches: chr1:70981161-70981561
# Did not find this label in motif matches: chr4:1325667-1326067
# Did not find this label in motif matches: chr1:88658617-88659017
# Did not find this label in motif matches: chr1:153829505-153829905
# Did not find this label in motif matches: chr1:201043701-201044101
# Did not find this label in motif matches: chr1:156655582-156655982
# Did not find this label in motif matches: chr1:53202196-53202596
# Did not find this label in motif matches: chr1:94694018-94694418
# Did not find this label in motif matches: chr18:49019090-49019490
# Did not find this label in motif matches: chr10:133479716-133480116
# Did not find this label in motif matches: chr1:145827300-145827700
# Did not find this label in motif matches: chr1:26163226-26163626
# Did not find this label in motif matches: chr1:23582225-23582625
# Did not find this label in motif matches: chr1:149936897-149937297
# Did not find this label in motif matches: chr1:161081495-161081895
# Did not find this label in motif matches: chr1:151690648-151691048
# Did not find this label in motif matches: chr1:184234861-184235261
# Did not find this label in motif matches: chr1:77346903-77347303
# Did not find this label in motif matches: chr1:23076306-23076706
# Did not find this label in motif matches: chr1:153104081-153104481
# Did not find this label in motif matches: chr17:42421809-42422209
# Did not find this label in motif matches: chr1:11322074-11322474
# Did not find this label in motif matches: chr1:112453126-112453526
# Did not find this label in motif matches: chr1:161285631-161286031
# Did not find this label in motif matches: chr1:52153348-52153748
# Did not find this label in motif matches: chr17:76470326-76470726
# Did not find this label in motif matches: chr1:71301603-71302003
# Did not find this label in motif matches: chr1:95610528-95610928
# Did not find this label in motif matches: chr1:33413904-33414304
# Did not find this label in motif matches: chr1:61984189-61984589
# Did not find this label in motif matches: chr18:76494632-76495032
# Did not find this label in motif matches: chr1:89166005-89166405
# Did not find this label in motif matches: chr1:181024312-181024712
# Did not find this label in motif matches: chrX:49878193-49878593
# Did not find this label in motif matches: chr1:63719300-63719700
# Did not find this label in motif matches: chr1:152602649-152603049
# Did not find this label in motif matches: chr1:57140454-57140854
# Did not find this label in motif matches: chr1:16164650-16165050
# Did not find this label in motif matches: chr11:44944875-44945275
# Did not find this label in motif matches: chr1:154823752-154824152
# Did not find this label in motif matches: chr20:31870203-31870603
# Did not find this label in motif matches: chr1:13825356-13825756
# Did not find this label in motif matches: chr1:27667811-27668211
# Did not find this label in motif matches: chr12:95790080-95790480
# Did not find this label in motif matches: chr11:2693076-2693476
# Did not find this label in motif matches: chr19:49107788-49108188
# Did not find this label in motif matches: chr22:23386264-23386664
# Did not find this label in motif matches: chr1:93436034-93436434
# Did not find this label in motif matches: chr1:76134288-76134688
# Did not find this label in motif matches: chr1:168644747-168645147
# Did not find this label in motif matches: chr1:12817315-12817715
# Did not find this label in motif matches: chr1:19179542-19179942
# Did not find this label in motif matches: chr1:57251023-57251423
# 731
# Did not find this label in motif matches: chr1:26505989-26506389
# Did not find this label in motif matches: chr1:61576450-61576850
# Did not find this label in motif matches: chr1:211039383-211039783
# Did not find this label in motif matches: chr1:10185041-10185441
# Did not find this label in motif matches: chr1:145387405-145387805
# Did not find this label in motif matches: chr10:102415660-102416060
# Did not find this label in motif matches: chr1:40605349-40605749
# Did not find this label in motif matches: chr1:26004278-26004678
# Did not find this label in motif matches: chr1:82762729-82763129
# Did not find this label in motif matches: chr1:200457291-200457691
# Did not find this label in motif matches: chr1:181767165-181767565
# Did not find this label in motif matches: chr1:98272169-98272569
# Did not find this label in motif matches: chr1:60961657-60962057
# Did not find this label in motif matches: chr1:71293378-71293778
# Did not find this label in motif matches: chr1:15081929-15082329
# Did not find this label in motif matches: chr1:56542335-56542735
# Did not find this label in motif matches: chr1:110280032-110280432
# Did not find this label in motif matches: chr1:42174982-42175382
# Did not find this label in motif matches: chr1:98712451-98712851
# Did not find this label in motif matches: chr8:143080880-143081280
# Did not find this label in motif matches: chr1:151263302-151263702
# Did not find this label in motif matches: chr1:14802538-14802938
# Did not find this label in motif matches: chr1:36955537-36955937
# Did not find this label in motif matches: chr1:110653198-110653598
# Did not find this label in motif matches: chr14:105388404-105388804
# Did not find this label in motif matches: chr1:26872815-26873215
# Did not find this label in motif matches: chr1:26715565-26715965
# Did not find this label in motif matches: chr1:76878967-76879367
# Did not find this label in motif matches: chr1:116931128-116931528
# Did not find this label in motif matches: chr1:67289975-67290375
# Did not find this label in motif matches: chr1:67589653-67590053
# Did not find this label in motif matches: chr20:32176739-32177139
# Did not find this label in motif matches: chr1:151283518-151283918
# Did not find this label in motif matches: chr11:68043828-68044228
# Did not find this label in motif matches: chr11:2217897-2218297
# Did not find this label in motif matches: chr1:99415345-99415745
# Did not find this label in motif matches: chr1:156841014-156841414
# Did not find this label in motif matches: chr1:22513945-22514345
# Did not find this label in motif matches: chr1:145138633-145139033
# Did not find this label in motif matches: chr2:199455774-199456174
# Did not find this label in motif matches: chr1:209423833-209424233
# Did not find this label in motif matches: chr1:112383326-112383726
# Did not find this label in motif matches: chr12:124322253-124322653
# Did not find this label in motif matches: chr1:4272903-4273303
# Did not find this label in motif matches: chr1:183106430-183106830
# Did not find this label in motif matches: chr10:133059828-133060228
# Did not find this label in motif matches: chr1:101123224-101123624
# Did not find this label in motif matches: chr11:65852058-65852458
# Did not find this label in motif matches: chr1:1021517-1021917
# Did not find this label in motif matches: chr1:120438371-120438771
# Did not find this label in motif matches: chr1:100323992-100324392
# Did not find this label in motif matches: chr1:18699099-18699499
# Did not find this label in motif matches: chr1:26686876-26687276
# Did not find this label in motif matches: chr1:43430500-43430900
# Did not find this label in motif matches: chr1:228183357-228183757
# Did not find this label in motif matches: chr1:68987524-68987924
# Did not find this label in motif matches: chr19:3120895-3121295
# Did not find this label in motif matches: chr1:92097004-92097404
# Did not find this label in motif matches: chr1:11938808-11939208
# Did not find this label in motif matches: chr1:175493824-175494224
# Did not find this label in motif matches: chr1:223444312-223444712
# Did not find this label in motif matches: chr1:44037260-44037660
# Did not find this label in motif matches: chr1:109435301-109435701
# Did not find this label in motif matches: chr1:156345386-156345786
# Did not find this label in motif matches: chr13:113015853-113016253
# Did not find this label in motif matches: chr1:84404497-84404897
# Did not find this label in motif matches: chr10:73853029-73853429
# Did not find this label in motif matches: chr4:6353514-6353914
# Did not find this label in motif matches: chr1:13038001-13038401
# Did not find this label in motif matches: chr11:64081428-64081828
# Did not find this label in motif matches: chr1:9148342-9148742
# Did not find this label in motif matches: chr1:111502859-111503259
# Did not find this label in motif matches: chr12:51913052-51913452
# Did not find this label in motif matches: chr16:56316461-56316861
# Did not find this label in motif matches: chr1:112717048-112717448
# Did not find this label in motif matches: chr1:97046830-97047230
# Did not find this label in motif matches: chr12:106477237-106477637
# Did not find this label in motif matches: chr12:113186730-113187130
# Did not find this label in motif matches: chr1:33347569-33347969
# Did not find this label in motif matches: chr1:49900489-49900889
# Did not find this label in motif matches: chr1:102239980-102240380
# Did not find this label in motif matches: chr1:6282208-6282608
# Did not find this label in motif matches: chr1:4673877-4674277
# Did not find this label in motif matches: chr1:71972070-71972470
# Did not find this label in motif matches: chr1:164930440-164930840
# Did not find this label in motif matches: chr16:70051688-70052088
# Did not find this label in motif matches: chr1:95324247-95324647
# Did not find this label in motif matches: chrX:80591466-80591866
# Did not find this label in motif matches: chr1:62079448-62079848
# Did not find this label in motif matches: chr1:42248305-42248705
# Did not find this label in motif matches: chr11:69921947-69922347
# Did not find this label in motif matches: chr1:200351124-200351524
# Did not find this label in motif matches: chr1:22415742-22416142
# Did not find this label in motif matches: chr1:36448077-36448477
# Did not find this label in motif matches: chr1:34605860-34606260
# Did not find this label in motif matches: chr17:20984023-20984423
# Did not find this label in motif matches: chr11:73381355-73381755
# Did not find this label in motif matches: chr1:160693167-160693567
# Did not find this label in motif matches: chr1:52144661-52145061
# Did not find this label in motif matches: chr1:92319919-92320319
# Did not find this label in motif matches: chr1:1188386-1188786
# Did not find this label in motif matches: chr17:68197559-68197959
# Did not find this label in motif matches: chr10:69803819-69804219
# Did not find this label in motif matches: chr1:168480338-168480738
# Did not find this label in motif matches: chr16:89299593-89299993
# Did not find this label in motif matches: chr1:157622402-157622802
# Did not find this label in motif matches: chr1:54557903-54558303
# Did not find this label in motif matches: chr8:143565386-143565786
# Did not find this label in motif matches: chr1:49993024-49993424
# Did not find this label in motif matches: chr1:30324021-30324421
# Did not find this label in motif matches: chr1:85173208-85173608
# Did not find this label in motif matches: chr1:14826046-14826446
# Did not find this label in motif matches: chr12:48168703-48169103
# Did not find this label in motif matches: chr1:43708937-43709337
# Did not find this label in motif matches: chr1:157880083-157880483
# Did not find this label in motif matches: chr1:51526379-51526779
# Did not find this label in motif matches: chr9:137317767-137318167
# Did not find this label in motif matches: chr9:81687616-81688016
# Did not find this label in motif matches: chr1:53594411-53594811
# Did not find this label in motif matches: chr1:90865257-90865657
# Did not find this label in motif matches: chr1:33942573-33942973
# Did not find this label in motif matches: chr1:8358843-8359243
# Did not find this label in motif matches: chr1:155048205-155048605
# Did not find this label in motif matches: chr1:55061118-55061518
# Did not find this label in motif matches: chr1:102213150-102213550
# Did not find this label in motif matches: chr1:89968750-89969150
# Did not find this label in motif matches: chr1:44750327-44750727
# Did not find this label in motif matches: chr1:34518770-34519170
# Did not find this label in motif matches: chr1:170850533-170850933
# Did not find this label in motif matches: chr1:23096382-23096782
# Did not find this label in motif matches: chr1:14278965-14279365
# Did not find this label in motif matches: chr1:171665745-171666145
# Did not find this label in motif matches: chr1:151593272-151593672
# Did not find this label in motif matches: chr1:183577897-183578297
# Did not find this label in motif matches: chr11:502638-503038
# Did not find this label in motif matches: chr1:150469212-150469612
# Did not find this label in motif matches: chr15:99486344-99486744
# Did not find this label in motif matches: chr1:7110628-7111028
# Did not find this label in motif matches: chr17:78137482-78137882
# Did not find this label in motif matches: chr1:45846436-45846836
# Did not find this label in motif matches: chr1:22217081-22217481
# Did not find this label in motif matches: chr13:99389964-99390364
# Did not find this label in motif matches: chr1:45590701-45591101
# Did not find this label in motif matches: chr1:81450198-81450598
# Did not find this label in motif matches: chr1:118611963-118612363
# Did not find this label in motif matches: chr1:150720854-150721254
# Did not find this label in motif matches: chr1:22960058-22960458
# Did not find this label in motif matches: chr1:40362045-40362445
# Did not find this label in motif matches: chr12:123491038-123491438
# Did not find this label in motif matches: chr1:41564214-41564614
# Did not find this label in motif matches: chr1:4524083-4524483
# Did not find this label in motif matches: chr19:1912754-1913154
# Did not find this label in motif matches: chr1:108536030-108536430
# Did not find this label in motif matches: chr1:153879964-153880364
# Did not find this label in motif matches: chr1:8433086-8433486
# Did not find this label in motif matches: chr1:108358422-108358822
# Did not find this label in motif matches: chr1:205488077-205488477
# Did not find this label in motif matches: chr1:59389970-59390370
# Did not find this label in motif matches: chr1:56963243-56963643
# Did not find this label in motif matches: chr10:130561339-130561739
# Did not find this label in motif matches: chr1:118129837-118130237
# Did not find this label in motif matches: chr1:23152764-23153164
# Did not find this label in motif matches: chr1:235027822-235028222
# Did not find this label in motif matches: chrX:96512425-96512825
# Did not find this label in motif matches: chr1:210597790-210598190
# Did not find this label in motif matches: chr1:56018160-56018560
# Did not find this label in motif matches: chr1:143534388-143534788
# Did not find this label in motif matches: chr1:58615354-58615754
# Did not find this label in motif matches: chr1:43957926-43958326
# Did not find this label in motif matches: chr1:41144630-41145030
# Did not find this label in motif matches: chr22:37426782-37427182
# Did not find this label in motif matches: chr1:230448906-230449306
# Did not find this label in motif matches: chr1:74853910-74854310
# Did not find this label in motif matches: chr1:50760767-50761167
# Did not find this label in motif matches: chr1:65860994-65861394
# Did not find this label in motif matches: chr1:28448151-28448551
# Did not find this label in motif matches: chr1:1446741-1447141
# Did not find this label in motif matches: chr1:206083598-206083998
# Did not find this label in motif matches: chr1:67579988-67580388
# Did not find this label in motif matches: chr1:37092006-37092406
# Did not find this label in motif matches: chr1:150155628-150156028
# Did not find this label in motif matches: chr1:84587972-84588372
# Did not find this label in motif matches: chr1:59777694-59778094
# Did not find this label in motif matches: chr1:98960149-98960549
# Did not find this label in motif matches: chr1:49148967-49149367
# Did not find this label in motif matches: chr13:113800907-113801307
# Did not find this label in motif matches: chr1:21306884-21307284
# Did not find this label in motif matches: chr1:56099685-56100085
# Did not find this label in motif matches: chr1:11131482-11131882
# Did not find this label in motif matches: chr1:64153452-64153852
# Did not find this label in motif matches: chr1:57940577-57940977
# Did not find this label in motif matches: chr1:152729708-152730108
# Did not find this label in motif matches: chr11:2203818-2204218
# Did not find this label in motif matches: chr1:217139129-217139529
# Did not find this label in motif matches: chr1:112425294-112425694
# Did not find this label in motif matches: chr1:151948806-151949206
# Did not find this label in motif matches: chr1:7258370-7258770
# Did not find this label in motif matches: chr1:64455748-64456148
# Did not find this label in motif matches: chr1:36445445-36445845
# Did not find this label in motif matches: chr1:74286692-74287092
# Did not find this label in motif matches: chr1:89030048-89030448
# Did not find this label in motif matches: chr11:44980865-44981265
# Did not find this label in motif matches: chr1:102005274-102005674
# Did not find this label in motif matches: chr1:95235569-95235969
# Did not find this label in motif matches: chr15:74603566-74603966
# Did not find this label in motif matches: chr10:70533857-70534257
# Did not find this label in motif matches: chr1:105893031-105893431
# Did not find this label in motif matches: chr12:49339518-49339918
# Did not find this label in motif matches: chr1:78048856-78049256
# Did not find this label in motif matches: chr1:175492245-175492645
# Did not find this label in motif matches: chr1:37420069-37420469
# Did not find this label in motif matches: chr2:118835845-118836245
# Did not find this label in motif matches: chr1:1142252-1142652
# Did not find this label in motif matches: chr1:98309190-98309590
# Did not find this label in motif matches: chrX:29333542-29333942
# Did not find this label in motif matches: chr10:1102003-1102403
# Did not find this label in motif matches: chr12:71421115-71421515
# Did not find this label in motif matches: chr1:46501204-46501604
# Did not find this label in motif matches: chr17:74860768-74861168
# Did not find this label in motif matches: chr16:56647934-56648334
# Did not find this label in motif matches: chr1:9318065-9318465
# Did not find this label in motif matches: chr1:28837512-28837912
# Did not find this label in motif matches: chr5:147234767-147235167
# Did not find this label in motif matches: chr11:69484473-69484873
# Did not find this label in motif matches: chr16:154410-154810
# Did not find this label in motif matches: chr1:37118965-37119365
# Did not find this label in motif matches: chr14:100834873-100835273
# Did not find this label in motif matches: chr1:100500245-100500645
# Did not find this label in motif matches: chr1:3380496-3380896
# Did not find this label in motif matches: chr1:66561959-66562359
# Did not find this label in motif matches: chr19:1020555-1020955
# Did not find this label in motif matches: chr1:102083976-102084376
# Did not find this label in motif matches: chr9:113112887-113113287
# Did not find this label in motif matches: chr1:28465846-28466246
# Did not find this label in motif matches: chr1:72171137-72171537
# Did not find this label in motif matches: chr10:81772399-81772799
# Did not find this label in motif matches: chr1:160912163-160912563
# Did not find this label in motif matches: chr1:119124942-119125342
# Did not find this label in motif matches: chr1:147099757-147100157
# Did not find this label in motif matches: chr1:23848585-23848985
# Did not find this label in motif matches: chr1:91701364-91701764
# Did not find this label in motif matches: chr12:125013614-125014014
# Did not find this label in motif matches: chr11:75719840-75720240
# Did not find this label in motif matches: chr1:41345176-41345576
# Did not find this label in motif matches: chr1:167333639-167334039
# Did not find this label in motif matches: chr10:101262905-101263305
# Did not find this label in motif matches: chr1:158930466-158930866
# Did not find this label in motif matches: chr1:59616198-59616598
# Did not find this label in motif matches: chr1:176563732-176564132
# Did not find this label in motif matches: chr1:55313219-55313619
# Did not find this label in motif matches: chr1:5294898-5295298
# Did not find this label in motif matches: chr1:84027771-84028171
# Did not find this label in motif matches: chr1:75196594-75196994
# Did not find this label in motif matches: chr15:75362341-75362741
# Did not find this label in motif matches: chr1:30884729-30885129
# Did not find this label in motif matches: chr1:10268123-10268523
# Did not find this label in motif matches: chr11:47257671-47258071
# Did not find this label in motif matches: chr1:49098442-49098842
# Did not find this label in motif matches: chr1:35310519-35310919
# Did not find this label in motif matches: chr1:225945148-225945548
# Did not find this label in motif matches: chr1:33450570-33450970
# Did not find this label in motif matches: chr1:33492222-33492622
# Did not find this label in motif matches: chr1:157985902-157986302
# Did not find this label in motif matches: chr1:1950456-1950856
# Did not find this label in motif matches: chr1:106877764-106878164
# Did not find this label in motif matches: chr1:147199882-147200282
# Did not find this label in motif matches: chr1:59086543-59086943
# Did not find this label in motif matches: chr1:173862806-173863206
# Did not find this label in motif matches: chr1:82063775-82064175
# Did not find this label in motif matches: chr1:45299518-45299918
# Did not find this label in motif matches: chr1:11480043-11480443
# Did not find this label in motif matches: chr1:58488336-58488736
# Did not find this label in motif matches: chr9:131091361-131091761
# Did not find this label in motif matches: chr10:75265747-75266147
# Did not find this label in motif matches: chr1:85210128-85210528
# Did not find this label in motif matches: chr1:69285333-69285733
# Did not find this label in motif matches: chr1:176909043-176909443
# Did not find this label in motif matches: chr2:5696511-5696911
# Did not find this label in motif matches: chr1:8864125-8864525
# Did not find this label in motif matches: chr1:82823870-82824270
# Did not find this label in motif matches: chr1:162345128-162345528
# Did not find this label in motif matches: chr1:154451774-154452174
# Did not find this label in motif matches: chr1:27653954-27654354
# Did not find this label in motif matches: chr1:165916178-165916578
# Did not find this label in motif matches: chr1:116000553-116000953
# Did not find this label in motif matches: chr1:87315663-87316063
# Did not find this label in motif matches: chr1:89165559-89165959
# Did not find this label in motif matches: chr1:24673572-24673972
# Did not find this label in motif matches: chr11:89983608-89984008
# Did not find this label in motif matches: chr8:30027229-30027629
# Did not find this label in motif matches: chr1:47644262-47644662
# Did not find this label in motif matches: chr1:5653920-5654320
# Did not find this label in motif matches: chr1:166980293-166980693
# Did not find this label in motif matches: chr1:15229930-15230330
# Did not find this label in motif matches: chr1:40310724-40311124
# Did not find this label in motif matches: chr1:109636431-109636831
# Did not find this label in motif matches: chr12:57495128-57495528
# Did not find this label in motif matches: chr10:132170610-132171010
# Did not find this label in motif matches: chr1:116453409-116453809
# Did not find this label in motif matches: chr1:31912032-31912432
# Did not find this label in motif matches: chr1:26198073-26198473
# Did not find this label in motif matches: chr1:17994906-17995306
# Did not find this label in motif matches: chr1:22054389-22054789
# Did not find this label in motif matches: chr1:53131494-53131894
# Did not find this label in motif matches: chr1:109211356-109211756
# Did not find this label in motif matches: chr1:63259212-63259612
# Did not find this label in motif matches: chr1:153718090-153718490
# Did not find this label in motif matches: chr11:3396994-3397394
# Did not find this label in motif matches: chr17:6453616-6454016
# Did not find this label in motif matches: chr1:22403738-22404138
# Did not find this label in motif matches: chr16:173431-173831
# Did not find this label in motif matches: chr1:80017549-80017949
# Did not find this label in motif matches: chr1:72570399-72570799
# Did not find this label in motif matches: chr1:7629792-7630192
# Did not find this label in motif matches: chr1:94093733-94094133
# Did not find this label in motif matches: chr1:119906702-119907102
# Did not find this label in motif matches: chr20:4162055-4162455
# Did not find this label in motif matches: chr1:11518370-11518770
# Did not find this label in motif matches: chr1:24323700-24324100
# Did not find this label in motif matches: chr10:12328466-12328866
# Did not find this label in motif matches: chr9:136046928-136047328
# Did not find this label in motif matches: chr1:9476019-9476419
# Did not find this label in motif matches: chr1:45120705-45121105
# Did not find this label in motif matches: chr2:42494160-42494560
# Did not find this label in motif matches: chr11:1466892-1467292
# Did not find this label in motif matches: chr1:176566404-176566804
# Did not find this label in motif matches: chr1:60693046-60693446
# Did not find this label in motif matches: chr1:58742563-58742963
# Did not find this label in motif matches: chr1:66718498-66718898
# Did not find this label in motif matches: chr1:6910103-6910503
# Did not find this label in motif matches: chr1:7911414-7911814
# Did not find this label in motif matches: chr1:95405812-95406212
# Did not find this label in motif matches: chr1:38379909-38380309
# Did not find this label in motif matches: chr2:112139025-112139425
# Did not find this label in motif matches: chr1:11161624-11162024
# Did not find this label in motif matches: chr1:184928292-184928692
# Did not find this label in motif matches: chr1:162118275-162118675
# Did not find this label in motif matches: chr1:112293498-112293898
# Did not find this label in motif matches: chr1:8902422-8902822
# Did not find this label in motif matches: chr1:53798149-53798549
# Did not find this label in motif matches: chr1:55039399-55039799
# Did not find this label in motif matches: chr1:108123518-108123918
# Did not find this label in motif matches: chr1:147285450-147285850
# Did not find this label in motif matches: chr1:158752249-158752649
# Did not find this label in motif matches: chr1:153457775-153458175
# Did not find this label in motif matches: chr1:16889792-16890192
# Did not find this label in motif matches: chr1:165022186-165022586
# Did not find this label in motif matches: chr12:132290749-132291149
# Did not find this label in motif matches: chr13:99087132-99087532
# Did not find this label in motif matches: chr1:9160049-9160449
# Did not find this label in motif matches: chr1:44137109-44137509
# Did not find this label in motif matches: chr1:161073848-161074248
# Did not find this label in motif matches: chr10:71246193-71246593
# Did not find this label in motif matches: chr10:1186337-1186737
# Did not find this label in motif matches: chr1:182399294-182399694
# Did not find this label in motif matches: chr1:58888331-58888731
# Did not find this label in motif matches: chr9:136108945-136109345
# Did not find this label in motif matches: chr17:37985823-37986223
# Did not find this label in motif matches: chr17:79839931-79840331
# Did not find this label in motif matches: chr1:115148382-115148782
# Did not find this label in motif matches: chr1:48441418-48441818
# Did not find this label in motif matches: chr14:102929830-102930230
# Did not find this label in motif matches: chr1:88291815-88292215
# Did not find this label in motif matches: chr1:150166375-150166775
# Did not find this label in motif matches: chr10:29734748-29735148
# Did not find this label in motif matches: chr1:20567447-20567847
# Did not find this label in motif matches: chr1:67521104-67521504
# Did not find this label in motif matches: chr10:71964646-71965046
# Did not find this label in motif matches: chrX:153075283-153075683
# Did not find this label in motif matches: chr1:150723984-150724384
# ...
# Did not find this label in motif matches: chr1:74860103-74860503
# Did not find this label in motif matches: chr1:149948758-149949158
# Did not find this label in motif matches: chr1:6966350-6966750
# Did not find this label in motif matches: chr11:2144786-2145186
# Did not find this label in motif matches: chr1:166291208-166291608
# Did not find this label in motif matches: chr1:167696296-167696696
# Did not find this label in motif matches: chr1:71121546-71121946
# Did not find this label in motif matches: chr1:146710273-146710673
# Did not find this label in motif matches: chr1:155121378-155121778
# Did not find this label in motif matches: chr1:28128297-28128697
# Did not find this label in motif matches: chr11:119024833-119025233
# Did not find this label in motif matches: chr11:554384-554784
# Did not find this label in motif matches: chr10:125803557-125803957
# Did not find this label in motif matches: chr1:9905506-9905906
# Did not find this label in motif matches: chr19:5131703-5132103
# Did not find this label in motif matches: chr14:104506825-104507225
# Did not find this label in motif matches: chr1:114304010-114304410
# Did not find this label in motif matches: chr1:96987350-96987750
# Did not find this label in motif matches: chrX:137573985-137574385
# Did not find this label in motif matches: chr1:203554171-203554571
# Did not find this label in motif matches: chr1:34422945-34423345
# Did not find this label in motif matches: chr1:150978675-150979075
# Did not find this label in motif matches: chr18:33578475-33578875
# Did not find this label in motif matches: chr1:21658160-21658560
# Did not find this label in motif matches: chr1:112356738-112357138
# Did not find this label in motif matches: chr1:153427784-153428184
# Did not find this label in motif matches: chr1:68984601-68985001
# Did not find this label in motif matches: chr1:60928347-60928747
# Did not find this label in motif matches: chr1:88185739-88186139
# Did not find this label in motif matches: chr1:11789876-11790276
# Did not find this label in motif matches: chr1:19586627-19587027
# Did not find this label in motif matches: chr1:23819159-23819559
# Did not find this label in motif matches: chr1:46556692-46557092
# Did not find this label in motif matches: chr1:19279594-19279994
# Did not find this label in motif matches: chr1:204599066-204599466
# Did not find this label in motif matches: chr1:196124202-196124602
# Did not find this label in motif matches: chr1:204085146-204085546
# Did not find this label in motif matches: chr1:68451552-68451952
# Did not find this label in motif matches: chr1:155084013-155084413
# Did not find this label in motif matches: chr16:22325500-22325900
# Did not find this label in motif matches: chr1:153714292-153714692
# Did not find this label in motif matches: chr3:130002447-130002847
# Did not find this label in motif matches: chr1:86232490-86232890
# Did not find this label in motif matches: chr1:26115803-26116203
# Did not find this label in motif matches: chr1:39912347-39912747
# Did not find this label in motif matches: chr1:108732365-108732765
# Did not find this label in motif matches: chr1:10701996-10702396
# Did not find this label in motif matches: chr5:141945423-141945823
# Did not find this label in motif matches: chr1:157113812-157114212
# Did not find this label in motif matches: chr1:62573079-62573479
# Did not find this label in motif matches: chr1:62753377-62753777
# Did not find this label in motif matches: chr1:152830090-152830490
# Did not find this label in motif matches: chr6:43509319-43509719
# Did not find this label in motif matches: chr1:18386488-18386888
# Did not find this label in motif matches: chr8:142418237-142418637
# Did not find this label in motif matches: chr14:104354029-104354429
# Did not find this label in motif matches: chr17:47708375-47708775
# Did not find this label in motif matches: chr4:190083107-190083507
# Did not find this label in motif matches: chr1:71890527-71890927
# Did not find this label in motif matches: chr1:23588497-23588897
# Did not find this label in motif matches: chr1:95657406-95657806
# Did not find this label in motif matches: chr1:50831054-50831454
# Did not find this label in motif matches: chr16:2150630-2151030
# Did not find this label in motif matches: chr1:5657606-5658006
# Did not find this label in motif matches: chr1:156002330-156002730
# Did not find this label in motif matches: chr1:24451448-24451848
# Did not find this label in motif matches: chr1:46790681-46791081
# Did not find this label in motif matches: chr1:91471100-91471500
# Did not find this label in motif matches: chr8:22565280-22565680
# Did not find this label in motif matches: chr1:227949631-227950031
# Did not find this label in motif matches: chr1:18251253-18251653
# Did not find this label in motif matches: chr10:132355225-132355625
# Did not find this label in motif matches: chr1:55861683-55862083
# Did not find this label in motif matches: chr1:175875061-175875461
# Did not find this label in motif matches: chr1:100926330-100926730
# Did not find this label in motif matches: chr1:173460538-173460938
# Did not find this label in motif matches: chr1:158768996-158769396
# Did not find this label in motif matches: chr1:41307367-41307767
# Did not find this label in motif matches: chr1:227632469-227632869
# Did not find this label in motif matches: chr1:62369513-62369913
# Did not find this label in motif matches: chr1:175606534-175606934
# Did not find this label in motif matches: chr10:43782239-43782639
# Did not find this label in motif matches: chr1:176734202-176734602
# Did not find this label in motif matches: chr1:112738874-112739274
# Did not find this label in motif matches: chr1:33592259-33592659
# Did not find this label in motif matches: chr1:212760131-212760531
# Did not find this label in motif matches: chr11:17651572-17651972
# Did not find this label in motif matches: chr1:38099669-38100069
# Did not find this label in motif matches: chr1:108357265-108357665
# Did not find this label in motif matches: chr13:110616040-110616440
# Did not find this label in motif matches: chr3:13568346-13568746
# Did not find this label in motif matches: chr11:8292134-8292534
# Did not find this label in motif matches: chr1:110582654-110583054
# Did not find this label in motif matches: chr1:40401847-40402247
# Did not find this label in motif matches: chr1:16467601-16468001
# Did not find this label in motif matches: chr1:117203853-117204253
# Did not find this label in motif matches: chr1:22585827-22586227
# Did not find this label in motif matches: chr10:129919863-129920263
# Did not find this label in motif matches: chr1:101482502-101482902
# Did not find this label in motif matches: chr10:30725464-30725864
# Did not find this label in motif matches: chr11:712293-712693
# Did not find this label in motif matches: chr1:112871625-112872025
# Did not find this label in motif matches: chr11:63009031-63009431
# Did not find this label in motif matches: chr1:150538663-150539063
# Did not find this label in motif matches: chr1:43030062-43030462
# Did not find this label in motif matches: chr1:53759727-53760127
# Did not find this label in motif matches: chr11:29600104-29600504
# Did not find this label in motif matches: chr1:47427456-47427856
# Did not find this label in motif matches: chr10:110766735-110767135
# Did not find this label in motif matches: chr1:115112472-115112872
# Did not find this label in motif matches: chr1:71817350-71817750
# Did not find this label in motif matches: chr6:169973522-169973922
# Did not find this label in motif matches: chr12:52200215-52200615
# Did not find this label in motif matches: chr11:70869478-70869878
# Did not find this label in motif matches: chr1:46431130-46431530
# Did not find this label in motif matches: chr11:2013586-2013986
# Did not find this label in motif matches: chr12:54294909-54295309
# Did not find this label in motif matches: chr1:45224204-45224604
# Did not find this label in motif matches: chr1:71380805-71381205
# Did not find this label in motif matches: chr13:103599902-103600302
# Did not find this label in motif matches: chr1:56431159-56431559
# Did not find this label in motif matches: chr1:44957115-44957515
# Did not find this label in motif matches: chr1:16860267-16860667
# Did not find this label in motif matches: chr1:20160119-20160519
# Did not find this label in motif matches: chr1:38477594-38477994
# Did not find this label in motif matches: chr11:67303428-67303828
# Did not find this label in motif matches: chr16:75516629-75517029
# Did not find this label in motif matches: chr1:113317441-113317841
# Did not find this label in motif matches: chr1:208065618-208066018
# Did not find this label in motif matches: chr1:6801015-6801415
# Did not find this label in motif matches: chr1:43428758-43429158
# Did not find this label in motif matches: chr1:27866317-27866717
# Did not find this label in motif matches: chr3:127547879-127548279
# Did not find this label in motif matches: chr1:67102328-67102728
# Did not find this label in motif matches: chr1:61300843-61301243
# Did not find this label in motif matches: chr1:75984833-75985233
# Did not find this label in motif matches: chr1:59641598-59641998
# Did not find this label in motif matches: chr1:1270979-1271379
# Did not find this label in motif matches: chr1:154982176-154982576
# Did not find this label in motif matches: chr1:70740484-70740884
# Did not find this label in motif matches: chr16:70679533-70679933
# Did not find this label in motif matches: chr1:211636965-211637365
# Did not find this label in motif matches: chr1:144018465-144018865
# Did not find this label in motif matches: chr13:111020283-111020683
# Did not find this label in motif matches: chr1:153407026-153407426
# Did not find this label in motif matches: chr1:75487979-75488379
# Did not find this label in motif matches: chr1:6767544-6767944
# Did not find this label in motif matches: chr1:43692416-43692816
# Did not find this label in motif matches: chr1:151348300-151348700
# Did not find this label in motif matches: chr1:57530603-57531003
# Did not find this label in motif matches: chr1:59446533-59446933
# Did not find this label in motif matches: chr1:57502625-57503025
# Did not find this label in motif matches: chr1:26450487-26450887
# Did not find this label in motif matches: chr1:32304761-32305161
# Did not find this label in motif matches: chr1:35852079-35852479
# Did not find this label in motif matches: chr1:43868634-43869034
# Did not find this label in motif matches: chr1:11376258-11376658
# Did not find this label in motif matches: chr1:93428079-93428479
# Did not find this label in motif matches: chr1:76339652-76340052
# Did not find this label in motif matches: chr1:234972936-234973336
# Did not find this label in motif matches: chr2:212832368-212832768
# Did not find this label in motif matches: chr11:61907206-61907606
# Did not find this label in motif matches: chr1:54444902-54445302
# Did not find this label in motif matches: chr1:162691327-162691727
# Did not find this label in motif matches: chr1:68126763-68127163
# Did not find this label in motif matches: chr12:49954113-49954513
# Did not find this label in motif matches: chr1:58523012-58523412
# Did not find this label in motif matches: chr1:198829046-198829446
# Did not find this label in motif matches: chr1:199869966-199870366
# Did not find this label in motif matches: chr1:43331502-43331902
# Did not find this label in motif matches: chr1:47269590-47269990
# Did not find this label in motif matches: chr1:53884242-53884642
# Did not find this label in motif matches: chr1:44327153-44327553
# Did not find this label in motif matches: chr1:112253476-112253876
# Did not find this label in motif matches: chr1:177039518-177039918
# Did not find this label in motif matches: chr1:6875171-6875571
# Did not find this label in motif matches: chr21:43074941-43075341
# Did not find this label in motif matches: chr1:34637547-34637947
# Did not find this label in motif matches: chr1:6253253-6253653
# Did not find this label in motif matches: chr22:50679020-50679420
# Did not find this label in motif matches: chr1:35407923-35408323
# Did not find this label in motif matches: chr1:58172797-58173197
# Did not find this label in motif matches: chr1:15676155-15676555
# Did not find this label in motif matches: chr4:183818759-183819159
# Did not find this label in motif matches: chr1:11332526-11332926
# Did not find this label in motif matches: chr1:51589774-51590174
# Did not find this label in motif matches: chr1:112346091-112346491
# Did not find this label in motif matches: chr9:93948603-93949003
# Did not find this label in motif matches: chr1:26894008-26894408
# Did not find this label in motif matches: chr14:102750996-102751396
# Did not find this label in motif matches: chr1:155672995-155673395
# Did not find this label in motif matches: chr1:68418502-68418902
# Did not find this label in motif matches: chr1:165090626-165091026
# Did not find this label in motif matches: chr1:25749194-25749594
# Did not find this label in motif matches: chr1:27583139-27583539
# Did not find this label in motif matches: chr1:159958934-159959334
# Did not find this label in motif matches: chr1:110590308-110590708
# Did not find this label in motif matches: chr13:40664513-40664913
# Did not find this label in motif matches: chr1:63864270-63864670
# Did not find this label in motif matches: chr1:33820059-33820459
# Did not find this label in motif matches: chr1:36092902-36093302
# Did not find this label in motif matches: chr1:88578556-88578956
# Did not find this label in motif matches: chr19:5115311-5115711
# Did not find this label in motif matches: chr1:167736555-167736955
# Did not find this label in motif matches: chr1:9667820-9668220
# Did not find this label in motif matches: chr21:46057011-46057411
# Did not find this label in motif matches: chr1:205446527-205446927
# Did not find this label in motif matches: chr1:65014634-65015034
# Did not find this label in motif matches: chr1:174768227-174768627
# Did not find this label in motif matches: chr1:3844127-3844527
# Did not find this label in motif matches: chr6:32061277-32061677
# Did not find this label in motif matches: chr1:18487515-18487915
# Did not find this label in motif matches: chr1:57926508-57926908
# Did not find this label in motif matches: chr1:15568363-15568763
# Did not find this label in motif matches: chr1:18198997-18199397
# Did not find this label in motif matches: chr11:66340014-66340414
# Did not find this label in motif matches: chr1:48093164-48093564
# Did not find this label in motif matches: chr22:19149545-19149945
# Did not find this label in motif matches: chr10:13162645-13163045
# Did not find this label in motif matches: chr1:37309723-37310123
# Did not find this label in motif matches: chr1:31573448-31573848
# Did not find this label in motif matches: chr1:200333341-200333741
# Did not find this label in motif matches: chr1:17482125-17482525
# Did not find this label in motif matches: chr1:92637157-92637557
# Did not find this label in motif matches: chr2:26848176-26848576
# Did not find this label in motif matches: chr1:46466267-46466667
# Did not find this label in motif matches: chr1:73956813-73957213
# Did not find this label in motif matches: chr1:118930389-118930789
# Did not find this label in motif matches: chr11:120527510-120527910
# Did not find this label in motif matches: chr1:1499009-1499409
# Did not find this label in motif matches: chr11:119935420-119935820
# Did not find this label in motif matches: chr21:44424524-44424924
# Did not find this label in motif matches: chr1:156439790-156440190
# Did not find this label in motif matches: chr19:1085995-1086395
# Did not find this label in motif matches: chr14:99174636-99175036
# Did not find this label in motif matches: chr1:199760158-199760558
# Did not find this label in motif matches: chr1:26430925-26431325
# Did not find this label in motif matches: chr1:46212072-46212472
# Did not find this label in motif matches: chr1:117115506-117115906
# Did not find this label in motif matches: chr1:120347395-120347795
# Did not find this label in motif matches: chr1:228072929-228073329
# Did not find this label in motif matches: chr1:155976246-155976646
# Did not find this label in motif matches: chr1:165494362-165494762
# 37191
# 37191
# (37191, 400)

# %%
for index in range(0,len(ig_seq_ids_of_interest)):
    ig_seq_ids_of_interest[index]=rename(ig_seq_ids_of_interest[index])

# %%
import re
method_to_saved_scores = OrderedDict([
    ('grad_times_input', grad_times_input_scores),
    ('rescale_all', rescale_all_scores),
    ('rescale_conv', rescale_conv_scores),
    #('guided_backprop', guided_backprop_scores),
    #('reveal_cancel', reveal_cancel_scores),
    ('integrated_gradients', ig_scores)

])
method_to_seq_id_to_scores = {}
for method_name in method_to_saved_scores:
    scores = method_to_saved_scores[method_name]
    if (method_name=='integrated_gradients'):
        assert(len(ig_seq_ids_of_interest)==len(scores))
        seq_id_to_scores = dict(zip(ig_seq_ids_of_interest,scores))
    else:
        print(len(seq_ids_of_interest))
        print(len(scores))
        assert(len(seq_ids_of_interest)==len(scores))
        seq_id_to_scores = dict(zip(relevant_labels_list,scores))
    method_to_seq_id_to_scores[method_name] = seq_id_to_scores


#covered_positions marks a position as a 1 if it overlaps
# an embedded motif
seq_id_to_covered_positions = {}
motif_id_to_hit_locations = defaultdict(list)
motif_id_to_motif_length = {}
#For each motif, we need a mapping from the motif
# to the positives locations
for seq_id in motif_matches:
    original_seq_id=seq_id
    #seq_id=rename(seq_id)
    if (method_name=='integrated_gradients'):
        if (seq_id in ig_seq_ids_of_interest):
            embedded_positions = np.zeros(seq_len)
            for embedding in motif_matches[original_seq_id]:
                the_seq=embedding['sequence']
                motif_start_loc = embedding['begin'] 
                motif_end_loc = embedding['end']
                motif_len = motif_end_loc-motif_start_loc
                embedded_positions[motif_start_loc:motif_end_loc] = 1.0
                motif_name = re.match('(\d+)-(\w+)-(\d+)',embedding['motif']).group(2)
                if (motif_name in motif_id_to_motif_length):
                    assert (motif_id_to_motif_length[motif_name]==motif_len)
                else:
                    motif_id_to_motif_length[motif_name] = motif_len
                motif_id_to_hit_locations[motif_name].append(
                    (seq_id,motif_start_loc))
            seq_id_to_covered_positions[seq_id] = embedded_positions 
    else:
        if (seq_id in seq_ids_of_interest_set):
            embedded_positions = np.zeros(seq_len)
            for embedding in motif_matches[original_seq_id]:
                the_seq=embedding['sequence']
                motif_start_loc = embedding['begin'] 
                motif_end_loc = embedding['end']
                motif_len = motif_end_loc-motif_start_loc
                embedded_positions[motif_start_loc:motif_end_loc] = 1.0
                motif_name = re.match('(\d+)-(\w+)-(\d+)',embedding['motif']).group(2)
                if (motif_name in motif_id_to_motif_length):
                    assert (motif_id_to_motif_length[motif_name]==motif_len)
                else:
                    motif_id_to_motif_length[motif_name] = motif_len
                motif_id_to_hit_locations[motif_name].append(
                    (seq_id,motif_start_loc))
        #print(embedded_positions)
            seq_id_to_covered_positions[seq_id] = embedded_positions 

total_motif_bases = 0
total_bases = 0
for (seqname, arr) in seq_id_to_covered_positions.items():
    total_motif_bases = total_motif_bases + np.sum(arr)
    total_bases = total_bases +  len(arr)
print("Motif positions: " + str(total_motif_bases) + ", total positions: " + str(total_bases))

#find windows of a given length that do not overlap any motif
motif_len_to_negatives = defaultdict(list)                            
for motif_len in set(motif_id_to_motif_length.values()):
    for seq_id,covered_positions in seq_id_to_covered_positions.items():
        cumsum = np.array([0]+list(np.cumsum(covered_positions)))
        window_sums = cumsum[motif_len:]-cumsum[0:-motif_len]
        null_windows = [(seq_id,x) for x in
                        np.nonzero(window_sums==0)[0]]
        motif_len_to_negatives[motif_len].extend(null_windows)
# Out:
# 37191
# 37191
# 37191
# 37191
# 37191
# 37191
# Motif positions: 163017.0, total positions: 400000

# %%
motif_id_to_pos_locs={}
for motif_id in motif_id_to_hit_locations:
    motif_len = motif_id_to_motif_length[motif_id]
    num_pos_locs = len(motif_id_to_hit_locations[motif_id])
    #num_neg_locs = len(motif_len_to_negatives[motif_len])
    motif_id_to_pos_locs.update({motif_id:float(num_pos_locs)})
print(len(motif_id_to_pos_locs))
top_5_motif_ids=sorted(motif_id_to_pos_locs, key=lambda x: motif_id_to_pos_locs[x])
#['TGAATGAATGAA', 'GGGGCGGGGC', 'AGAGGAAGTG', 'AAAAAAAAAAAA', 'AAAAAAAAAA', 'CTTCCTCT', 'GCCACTGCAC', 'AAAAAAAA', 'GGGTGGGG'] 
#top_5_motif_ids=sorted(motif_id_to_hit_locations, key=lambda x: len(motif_id_to_hit_locations[x]))[-5:]
#rescale_all_scores=np.random.rand(rescale_all_scores.shape[0], rescale_all_scores.shape[1])
# Out:
# 72

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 15}

matplotlib.rc('font', **font)

method_name_to_plot_style = {
    'grad_times_input': {'color':'green'},
    'rescale_all': {'color':'orange'},
    'rescale_conv': {'color':'purple'},
    'reveal_cancel': {'color': 'red'},
    'guided_backprop': {'color': 'yellow'},
    'integrated_gradients': {'color': 'blue'}
}

method_name_nicename = {
    'grad_times_input': 'grad_times_input',
    'rescale_all': 'rescale_all',
    'rescale_conv': 'rescale_conv',
    'reveal_cancel': 'reveal_cancel',
    'guided_backprop': 'guided_backprop',
    'integrated_gradients': 'integrated_gradients'
}
motif_info={}
print("Number of motifs is " + str(len(motif_id_to_motif_length.keys())))
for motif_id in sorted(top_5_motif_ids):
    
    for methods_to_plot in [['integrated_gradients']]:
    #[['grad_times_input', 'rescale_all', 'rescale_conv', 'reveal_cancel', 'guided_backprop', 'integrated_gradients']]:
        
        #print("On motif",motif_id)
        motif_len = motif_id_to_motif_length[motif_id]
        pos_locs = motif_id_to_hit_locations[motif_id]
        neg_locs = motif_len_to_negatives[motif_len]
        #print("num pos",len(pos_locs))
        #print("num neg",len(neg_locs))
        all_locs = list(pos_locs)+list(neg_locs)
        #print(len(motif_matches.items()))
        loc_labels = [1 for x in pos_locs]+[0 for x in neg_locs]

        #f,axarr = plt.subplots(1,2, figsize=(20,5))
        #plt.subplot(122)
        #plt.title(motif_id+' auROC Curves')
        #plt.plot([0, 1], [0, 1], color='black', linestyle='--')
        #plt.xlim([0, 1])
        #plt.ylim([0, 1])
        #plt.ylabel('True Positive Rate')
        #plt.xlabel('False Positive Rate')

        pos_frac = float(len(pos_locs))/(len(pos_locs)+len(neg_locs))
        #plt.subplot(121)
        #plt.title(motif_id+' auPRC Curves')
        #plt.plot([0, 1], [pos_frac, pos_frac], color='black', linestyle='--')
        #plt.xlim([0, 1])
        #plt.ylim([0, 1])
        #plt.ylabel('Precision')
        #plt.xlabel('Recall') 
    
        for method_name in methods_to_plot:
            #print(method_name)
            seq_id_to_windowsums = {}
            seq_id_to_scores=method_to_seq_id_to_scores[method_name]
            for seq_id,scores in seq_id_to_scores.items():
                #cumsum = np.array([0]+list(np.cumsum(np.sum(scores,axis=-1))))
                cumsum = np.array([0]+list(np.cumsum(scores)))
                windowsums = cumsum[motif_len:]-cumsum[:-motif_len]
                seq_id_to_windowsums[seq_id] = windowsums
            loc_scores = [seq_id_to_windowsums[seq_id][pos]
                          for (seq_id, pos) in all_locs]
            auroc = roc_auc_score(y_true=loc_labels,
                                  y_score=loc_scores)
            auprc = average_precision_score(y_true=loc_labels,
                                            y_score=loc_scores)
            #print("auROC: " + str(auroc))
            #print("auPRC: " + str(auprc))
            #print("Hits in pos set: " + str(motif_id_to_pos_locs[motif_id]))
            motif_info.update({motif_id:[auroc,auprc,motif_id_to_pos_locs[motif_id]]})
            """plt.subplot(122)
            fpr, tpr, rocthresholds = roc_curve(
                loc_labels, loc_scores, pos_label=1)
            plt.plot(fpr, tpr,
                     label = method_name_nicename[method_name]+(' AUC = %0.2f' % (100*auroc))+"%",
                     linewidth=2,
                     **method_name_to_plot_style[method_name])
            plt.legend(loc = 'lower right', fontsize='xx-small')

            plt.subplot(121)
            precision, recall, thresholds = precision_recall_curve(
                loc_labels, loc_scores, pos_label=1)
            plt.plot(precision, recall,
                     label = method_name_nicename[method_name]+(' AUC = %0.2f' % (100*auprc))+"%",
                     linewidth=2,
                     **method_name_to_plot_style[method_name])
            plt.legend(loc = 'top right', fontsize='xx-small')

        plt.show()"""

sorted_keys=(sorted(motif_info, key=lambda x: motif_info[x][1]))
for key in sorted_keys[::-1]:
    print(key+": "+str(motif_info[key]))
# Out:
# Number of motifs is 72
# GCCMYCTRGTGG: [0.9680042581898474, 0.8758710477294634, 301.0]
# CCCTCTAGTG: [0.9517912596211965, 0.8218815698920067, 272.0]
# CCACTAGAGG: [0.9241585161760232, 0.8090752957166482, 92.0]
# AGRTGGCA: [0.7800833049716049, 0.4843010691472057, 376.0]
# BCTGATTGGCYG: [0.9677621301063648, 0.4530303640731374, 426.0]
# GCCAATCG: [0.949404928907661, 0.4452850132297289, 580.0]
# TGATTGGYYS: [0.9343526128702258, 0.42821628267704215, 611.0]
# ATGACTCA: [0.8835060160231007, 0.3627347295174602, 188.0]
# RTGASTCAKH: [0.9156172801684402, 0.3610963255675638, 157.0]
# GGGGCGGGGC: [0.940624100002943, 0.33736519064864295, 1040.0]
# ATGASTCAKHNN: [0.9063210846603256, 0.32648175438318916, 161.0]
# NVGCCCCGCCCC: [0.9391862160178175, 0.32292698185089835, 985.0]
# BCGATTCGNN: [0.8893324919505505, 0.30830456892688274, 462.0]
# GCCCCGCC: [0.9207954940910426, 0.23108362987944348, 802.0]
# NGTGACGTCA: [0.9523121163182516, 0.21873793238730693, 126.0]
# CGCCCTWT: [0.8029419276544929, 0.19008256598466924, 907.0]
# VCCACTAG: [0.6185965947765824, 0.17412279942836062, 438.0]
# DRRGGSSRRR: [0.8602410668655407, 0.1624923921691785, 1019.0]
# CGGTGACGTCAS: [0.8610748777688556, 0.1513359475940253, 259.0]
# GACGTNAC: [0.7358092192784565, 0.11553485352506082, 651.0]
# GMCACGTNAC: [0.7222453179841406, 0.08997423119114643, 370.0]
# CTCCGCCC: [0.881437453536686, 0.07118275364849791, 505.0]
# STGCGCATGCGC: [0.9172758881573173, 0.06451073546031943, 102.0]
# RACCGGAAGT: [0.7870019884281642, 0.054836455293413466, 710.0]
# SAGTCATYTS: [0.6820944876622572, 0.054768295321715205, 201.0]
# YGCGCATGCG: [0.8975434188834659, 0.05458753840990774, 111.0]
# CCCCCCCCCCCC: [0.8449444603070166, 0.052593326993259804, 660.0]
# CGGAAGTG: [0.7471317838002809, 0.04845757320503927, 877.0]
# CNCGSAAGNNNN: [0.6924590104732827, 0.04733197246035084, 1226.0]
# VSCGGAAA: [0.6908997268166632, 0.04480286355279036, 1860.0]
# CGCATGCG: [0.8066242563304231, 0.039378063891681504, 167.0]
# SNCGYTAVBS: [0.6068095344580812, 0.03803505763973239, 728.0]
# NNDNCGGWHVNN: [0.7035296504898261, 0.03233278700573988, 898.0]
# GGGRRTTTYC: [0.6476754816889359, 0.028877530294041873, 1040.0]
# CACTTCCTSTTY: [0.724413966985531, 0.024934060258994174, 416.0]
# NTBTCGCGNV: [0.5997916257552275, 0.021219455474892682, 1179.0]
# GTGACTRA: [0.5713677087771802, 0.01901319859868402, 676.0]
# NWAACCACAR: [0.4517220405044049, 0.01873027863838661, 277.0]
# WAGBCCGC: [0.5832980227504128, 0.01692300393891738, 1251.0]
# CCGCCATCTT: [0.7797636636195526, 0.015951854365954934, 48.0]
# NNSDWWCGDHNB: [0.6027492835838197, 0.01480220638747268, 573.0]
# NBTYNNKYCG: [0.6444203226769596, 0.013118658119629388, 979.0]
# BNCGKTWH: [0.5659293677389479, 0.012736128057804066, 1425.0]
# GKAAGTGGYT: [0.6112519995714045, 0.012636876519256813, 303.0]
# YCGCDARK: [0.553265862653878, 0.011924256062145592, 1198.0]
# AVWAAVCSGC: [0.5702410055268734, 0.01172586877189611, 986.0]
# TTYCGSTT: [0.6831875378060464, 0.011406580331560641, 405.0]
# TGACAGCH: [0.5489367331192205, 0.0110343181575525, 572.0]
# CGAAACBGAACN: [0.5599133797799525, 0.010336067946851275, 553.0]
# AGACGACT: [0.5453928542875242, 0.009591851099381533, 280.0]
# GGGAATTGTAGT: [0.8548936380050677, 0.009152321249119697, 20.0]
# TTTCRSTTCC: [0.6555302367413507, 0.008210238476555613, 324.0]
# BCGGTTTC: [0.571985525622185, 0.007691393018813783, 809.0]
# TCCGAAYG: [0.5548530845192781, 0.006535752216541609, 862.0]
# BNCATTYGCRTA: [0.5880307004108922, 0.004937078722737364, 207.0]
# RNTCTCGCGAGA: [0.8491465246483683, 0.004554247048644278, 25.0]
# CGTTTCAG: [0.5367066098562715, 0.004081290196572352, 553.0]
# YGCCATGGCAAC: [0.7987250780334216, 0.0038418816643805594, 78.0]
# TCGCGAGA: [0.7867774360163801, 0.003473569655367875, 35.0]
# GGGAAATGTA: [0.7454522447984988, 0.003193296077817981, 24.0]
# TAACCACA: [0.40016881775381785, 0.0030750917864877797, 183.0]
# GGGAAWTCCCCN: [0.5748991002473182, 0.0027778118837761515, 48.0]
# AAGATGGCGGCS: [0.6992381310027765, 0.002081205178141585, 48.0]
# TGAAACYRNN: [0.509589009365483, 0.0019451268042184244, 228.0]
# NNNAAACCACAN: [0.4041600887912151, 0.0019069627390060624, 107.0]
# GGGGATTT: [0.5731792687653564, 0.0015739000118939134, 169.0]
# GTGCGAAA: [0.4794983020184177, 0.0014960785230916259, 258.0]
# ATGCAAATCV: [0.4800913145281884, 0.0013413889991875567, 181.0]
# TTCTCAGAAACT: [0.5446607933013122, 0.0008770183835590329, 73.0]
# TGGTTTCASTTY: [0.5727080672498412, 0.00022132301821583105, 17.0]
# ATKGAACSGA: [0.4048639388390905, 3.3178489413770124e-05, 4.0]
# CGAATGGAATCA: [0.4734284673858619, 2.7457668140077845e-05, 2.0]

# %% [markdown]
# # Sanity Check

# %% [markdown]
# #### Extract base pair sequences

# %%
shuffled_motifs={'SAGATAAV', 'NVCTTTYACA', 'NTRTCTAGCK', 'NNATGASTCATN', 'DCTGTRAAARVN', 'STTCYDGGAA', 'WGAAAAGCAG', 'CGCGGCGC', 'CAGCCAAANV', 'RCCAATCG', 'NBNTTATCTG', 'GGCGSCGSCG', 'CMYCTRGTGG', 'SNAAACMGCH', 'GGGGGAGGGGSN', 'AGGAAACG', 'CAGCCAMA', 'GNTCTCGCGAGA', 'AAAAGCHGNCTN', 'GCCGCTAG', 'AACAGCAG', 'VAGRYGGCGSCN', 'GCCCCGCCCC', 'NBTGTYTAGCTG', 'ACCAGAAG', 'YGTTTCCHNN', 'HRAATGGAAT', 'CCTTCCCC', 'TGTCTAGC', 'GCTTTGCAAA', 'AAAGCCDC', 'AAACCAGA', 'AAAGSCNNNN', 'CCCCNCCC', 'YGTTTACA', 'RMTGACWG', 'RKCWGTAAAR', 'YTTCTGGTTT', 'GCTCCTCC', 'ATGACWDCRN', 'GSGGGGGSGGSG', 'ATGACTCA', 'GCCMYCTRGTGG', 'ACTTCCTB', 'NWGATAANVNNN', 'NNGCGCVKSCGC', 'AGATAGGRNNNN', 'RCTTCCTBYYNN', 'CCGCGCGGCG', 'CTTTCACA', 'NVMGCNVGCG', 'BYTGCTGTTW', 'GTGTGTGT', 'GATGAGTCAT', 'RCCAATSVSNNN', 'GTGACDTC', 'HGTSACTTVD', 'GCTCCWCCCG', 'CSGCGGCG', 'NHGCAGAAAARA', 'NTSTGGCTKBHD', 'CGCCCTCT', 'CTTTCMCAGAAG', 'NDGTCACRTGAC', 'TTTACARWCCYT', 'RGAGGAAGYG', 'NNDGHAGTCACT', 'GWGTGTGTGT', 'NNNARACAGCAR', 'AGCGCGCG', 'NCMVCTCCCYCN', 'NGBCCCGCGVGV', 'GWGTGTGTGTGT', 'DGCTGTTW', 'NGGGYGGRGCSR'}
original_motifs={'AAAGCSDC', 'HGGCCCCGCCCC', 'ACCAATCG', 'NNDACNGCNS', 'TTGGWGAACCTT', 'CCAATCAG', 'CCCCTCCCCCNC', 'ACTTCCTSYTBN', 'CAGCCAAA', 'AGGGTTTGTAAA', 'ASMMAAACAS', 'STTATCWG', 'GGCGCGGGCGCG', 'GAGTGTGTGTGT', 'YTGTCAGB', 'RTGACGTCAYCS', 'TAAAAGCAGGCT', 'CMYCTAGYGG', 'ACTACRNYTCCC', 'GGCGGCGGCG', 'HKCGCGCG', 'CGCAAGATTTAT', 'TGBAAACG', 'AGTGACCTCTAG', 'VTCATGTGAC', 'TGTGAAAG', 'GCCMCGCC', 'DGTGACGTCA', 'CGCCGCCG', 'CACYAGRGGG', 'TGTCTAGC', 'GCWGHMAAAAMV', 'BYTSTGGTTT', 'CGCGCNNGCG', 'ATTATACGCTAA', 'RMTCTCGCGAGA', 'RRCCAATCRG', 'CTAGCGGC', 'CWGATAAGANNN', 'TBTRKCTAGCTV', 'GGGHGGAGCC', 'CTCCGCCC', 'GCCCCGCCCC', 'VTTCYNGGAA', 'ATGACTCA', 'TCGAATGGAATC', 'CYCTGTMAAA', 'KGCKGTTT', 'RASMGGAAGT', 'CTGCGCATGCGC', 'CCGCGCGGCG', 'DACAGCWG', 'NGVTGASTCATC', 'GATGAGTCAT', 'AAGATGGCGGCS', 'RCCAATCAGMDB', 'TGGTCTAGCGGT', 'CTTATCTSNN', 'GRGGRAGT', 'CCCCCCCC', 'GCCMCCTAGTGG', 'CCMCKCCCMC', 'CGCATGCG', 'CGCCCTCT', 'TKAGCATGCT', 'WGATAAVS', 'KVKCGCGVGA', 'RYCAYRTGRYHN', 'NBCTTATCTS', 'GTGACTWC', 'GTRTCTAGCT', 'CTTCCGGT', 'SGWTYGTRAA', 'AGCGCCCCCT'}
print ("Intersects:", shuffled_motifs.intersection(original_motifs))

# %%
import gzip
import re
from collections import OrderedDict
def load_sequences_from_bedfile(seqfile):
    seqs = OrderedDict()
    fp = gzip.open(seqfile, "rb")
    print("#Loading " + seqfile + " ...")
    for line in fp:
        (label, sequence)=line.split()
        seqs[label]=sequence
    fp.close()
    print("#Loaded " + str(len(seqs.keys())) + " sequences from " + seqfile)
    return seqs

# %%
def rename(label):
    match=re.match('.*_(chr.*)$',label)
    if match:
        return match.group(1)
    else:
        return ""

# %%
data_filename_positive = "/users/eprakash/projects/benchmarking/newdata/SPI1_in_K562/SPI1.pos.summits.implanted.bed.gz"
data_filename_negative = "/users/eprakash/projects/benchmarking/newdata/SPI1_in_K562/SPI1.neg.summits.implanted.bed.gz"
labeled_sequences = load_sequences_from_bedfile(data_filename_positive)
neg_seqs = load_sequences_from_bedfile(data_filename_negative)
labeled_sequences.update(neg_seqs)
sequences={}
for (label,seq) in labeled_sequences.items():
    sequences.update({rename(label):seq})

# %% [markdown]
# #### Select random 5 sequences for motif

# %%
from random import *
motif='CTTCCTTYCT'
motif_seqs=[value[0] for value in motif_id_to_hit_locations[motif]]
random_indices=[randint(0,len(motif_seqs)) for i in range(0,5)]
print (random_indices)
selected_seqs=[motif_seqs[i] for i in random_indices]
print (selected_seqs)

# %% [markdown]
# #### Onehot encode

# %%
def one_hot_encode_along_channel_axis(sequence):
    to_return = np.zeros((len(sequence),4), dtype=np.int8)
    seq_to_one_hot_fill_in_array(zeros_array=to_return,
                                 sequence=sequence, one_hot_axis=1)
    return to_return

def seq_to_one_hot_fill_in_array(zeros_array, sequence, one_hot_axis):
    assert one_hot_axis==0 or one_hot_axis==1
    if (one_hot_axis==0):
        assert zeros_array.shape[1] == len(sequence)
    elif (one_hot_axis==1): 
        assert zeros_array.shape[0] == len(sequence)
    #will mutate zeros_array
    for (i,char) in enumerate(sequence):
        if (char=="A" or char=="a"):
            char_idx = 0
        elif (char=="C" or char=="c"):
            char_idx = 1
        elif (char=="G" or char=="g"):
            char_idx = 2
        elif (char=="T" or char=="t"):
            char_idx = 3
        elif (char=="N" or char=="n"):
            continue #leave that pos as all 0's
        else:
            raise RuntimeError("Unsupported character: "+str(char))
        if (one_hot_axis==0):
            zeros_array[char_idx,i] = 1
        elif (one_hot_axis==1):
            zeros_array[i,char_idx] = 1
#sequences = sequences[-5000:]            
onehot_data = np.array([one_hot_encode_along_channel_axis(sequences[select_seq]) for select_seq in selected_seqs])

# %%
print (onehot_data.shape)

# %% [markdown]
# #### Get relevant scores

# %%
selected_relevant_indices_list=[list(labels).index(seq) for seq in selected_seqs]
selected_rescale_conv_scores=get_relevant_scores(selected_relevant_indices_list, original_rescale_conv_scores, seq_len)
print (selected_rescale_conv_scores.shape)

# %%
def split_sequence_by_motif_name(motif_name, list_of_dicts):
    list_with_motif = list()
    list_without_motif = list()
    for one_motif_occurrence in list_of_dicts:
        full_motif = one_motif_occurrence['motif']
        essential_motif = re.match('(\d+)-(\w+)-(\d+)',full_motif).group(2)
        if essential_motif == motif_name:
            list_with_motif.append(one_motif_occurrence)
        else:
            list_without_motif.append(one_motif_occurrence)
    return (list_with_motif, list_without_motif)

# %% [markdown]
# #### Visualization

# %%
# %matplotlib inline
from deeplift.visualization import viz_sequence
for i in range(0,len(selected_seqs)):
    scores=selected_grad_times_input_scores[i]
    seq_id=selected_seqs[i]
    print(seq_id)
    (list_with_motif, list_without_motif)=split_sequence_by_motif_name(motif, motif_matches[seq_id])
    viz_sequence.plot_weights(onehot_data[i]*scores[:, None], subticks_frequency=10, highlight={'blue':[(seq_info['begin'],seq_info['end']) for seq_info in list_with_motif]})
    viz_sequence.plot_weights(onehot_data[i]*scores[:, None], subticks_frequency=10, highlight={'red':[(seq_info['begin'],seq_info['end']) for seq_info in list_without_motif]})

# %%
pwm = np.array([[0.036,0.170,0.033,0.761],[0.001,0.635,0.125,0.239],[0.031,0.128,0.004,0.837],[0.001,0.676,0.166,0.157],
                [0.058,0.113,0.040,0.789],[0.007,0.676,0.207,0.110],[0.007,0.125,0.001,0.867],[0.001,0.660,0.206,0.133],
                [0.005,0.186,0.001,0.808],[0.001,0.607,0.241,0.151],[0.054,0.231,0.006,0.709],[0.025,0.540,0.217,0.218]])
print (pwm.shape)

# %%
# %matplotlib inline
from deeplift.visualization import viz_sequence
viz_sequence.plot_weights(pwm, subticks_frequency=10)
